# %%
import juliaset

# %%
import timeit

# %%
# %timeit -n 10 -r 5 juliaset.calc_pure_python(desired_width=1000, max_iterations=300)
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 4.29949426651001 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 4.004373073577881 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 3.9814746379852295 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 3.980020046234131 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 3.953155994415283 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 3.9609391689300537 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 4.21856427192688 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 3.99103045463562 seconds
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 3.965526580810547 seconds
# Length of x: 1000
# ...

# %%
import juliasetlite
import cProfile

# %%
cProfile.run("juliasetlite.calc_pure_python(desired_width=1000, max_iterations=300)", sort = "cumulative")
# Out:
# Length of x: 1000
# Total elements: 1000000
# calculate_z_serial_purepython took 10.082918405532837 seconds
#          36222123 function calls in 10.794 seconds
#
#    Ordered by: cumulative time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   10.794   10.794 {built-in method builtins.exec}
#         1    0.025    0.025   10.794   10.794 <string>:1(<module>)
#         1    0.545    0.545   10.769   10.769 juliasetlite.py:7(calc_pure_python)
#         1    7.622    7.622   10.083   10.083 juliasetlite.py:44(calculate_z_serial_purepython)
#  34219980    2.461    0.000    2.461    0.000 {built-in method builtins.abs}
#   2002000    0.136    0.000    0.136    0.000 {method 'append' of 'list' objects}
#         1    0.005    0.005    0.005    0.005 {built-in method builtins.sum}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#        14    0.000    0.000    0.000    0.000 iostream.py:624(write)
# ...
